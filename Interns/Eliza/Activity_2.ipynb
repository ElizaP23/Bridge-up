# %% [markdown]
# <a href="https://colab.research.google.com/github/ElizaP23/Bridge-up/blob/master/Interns/Eliza/Activity_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd 
import matplotlib.colors as mpl
import numpy as np

# %%
my_path='/content/gdrive/My Drive/EscapeEarthData/Activity-2/'

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df=pd.read_csv("{}df1.csv".format(my_path))
df.head()
# Out:
#        col1     col2
# 0  272.3966  45.8308
# 1  272.3288  45.9244
# 2  272.3307  45.9255
# 3  272.3711  47.2259
# 4  272.5282  47.0887

# %%
plt.scatter(df["col1"], df["col2"], s=0.25)

# %%
data2=pd.read_csv("{}df2.csv".format(my_path))
plt.scatter(data2["col1"], data2["col2"],s=0.25)

# %%
data3=pd.read_csv("{}df3.csv".format(my_path))
plt.scatter(data3["col1"], data3["col2"],s=0.25)

# %%
import astropy
from astropy.coordinates import SkyCoord

c_old = SkyCoord([df['col1'].to_numpy()], [df['col2'].to_numpy()], frame='icrs',unit='degree') #replace df1 if your variable names are different 
c_new = c_old.galactic
for count in range(len(c_new[0])):
        df_new_col1 = c_new[0].l.degree
        df_new_col2 = c_new[0].b.degree
new_data = {'col1':df_new_col1,'col2':df_new_col2}
df_new = pd.DataFrame(new_data)

# %%
import astropy
from astropy.coordinates import SkyCoord

c_old = SkyCoord([data2['col1'].to_numpy()], [data2['col2'].to_numpy()], frame='icrs',unit='degree') #replace df1 if your variable names are different 
c_new = c_old.galactic
for count in range(len(c_new[0])):
        data2_new_col1 = c_new[0].l.degree
        data2_new_col2 = c_new[0].b.degree
new_data = {'col1':df1_new_col1,'col2':df1_new_col2}
data2_new = pd.DataFrame(new_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-cacca0c49e11> in <module>()
#       5 c_new = c_old.galactic
#       6 for count in range(len(c_new[0])):
# ----> 7         df1_new_col1 = c_new[0].l.degree
#       8         df1_new_col2 = c_new[0].b.degree
#       9 new_data = {'col1':df1_new_col1,'col2':df1_new_col2}
#
# /usr/local/lib/python3.6/dist-packages/astropy/coordinates/sky_coordinate.py in __getattr__(self, attr)
#     595             # Some attributes might not fall in the above category but still
#     596             # are available through self._sky_coord_frame.
# --> 597             if not attr.startswith('_') and hasattr(self._sky_coord_frame, attr):
#     598                 return getattr(self._sky_coord_frame, attr)
#     599
#
# /usr/local/lib/python3.6/dist-packages/astropy/coordinates/baseframe.py in __getattr__(self, attr)
#    1549
# ...
